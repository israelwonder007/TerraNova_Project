# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
df_decl = pd.read_csv("../data/declarations.csv")
df_pa = pd.read_csv("../data/public_assistance.csv")
df_sum = pd.read_csv("../data/disaster_summaries.csv")

print("Datasets loaded")
# Out:
# Datasets loaded

# %%
def basic_info(df, name):
    print(f"\n{name} shape:", df.shape)
    print("\nColumns:")
    print(df.columns.tolist())
    
    print("\nMissing values:")
    print(df.isna().sum())
